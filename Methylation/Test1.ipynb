# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("data.csv")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-db786a48f0d5> in <module>()
#       1 data = pd.read_csv("data.csv")
# ----> 2 data['cg14817997']
#
# /home/ubuntu/anaconda3/envs/keras2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# /home/ubuntu/anaconda3/envs/keras2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of             200973410159_R03C01  200991620021_R01C01  200991620021_R03C01  \
# cg14817997             0.834027             0.849201             0.772995
# cg26928153             0.945589             0.948538             0.962199
# cg16269199             0.845186             0.911488             0.948206
# cg13869341             0.928455             0.885379             0.881643
# cg14008030             0.582476             0.536990             0.599218
# cg12045430             0.116920             0.097013             0.132622
# cg20826792             0.059963             0.083405             0.102972
# cg20253340             0.523214             0.539284             0.578563
# cg02404219             0.758915             0.670439             0.825726
# cg21870274             0.887897             0.863735             0.764876
# cg04098293             0.753801             0.646153             0.690489
# ...
